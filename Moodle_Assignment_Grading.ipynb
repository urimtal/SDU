# %% [markdown]
# <a href="https://colab.research.google.com/github/urimtal/SDU/blob/main/Moodle_Assignment_Grading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install beautifulsoup4 openpyxl

# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')

# 👇 EDIT this path to match your Google Drive exactly
BASE = Path('/content/drive/MyDrive/2025 Fall/Data Journalism 2025/Moodle Assignments')

# If your files have different names, switch to '*.html'
FILENAME_FILTER = 'onlinetext.html'   # or '*.html'

print("Base exists:", BASE.exists())
# Out:
# Mounted at /content/drive
# Base exists: True

# %%
from bs4 import BeautifulSoup
import pandas as pd

# Find files
files = list(BASE.rglob(FILENAME_FILTER)) if FILENAME_FILTER != '*.html' else list(BASE.rglob('*.html'))
print("Found HTML files:", len(files))
assert len(files) > 0, "No HTML files found. Check BASE or FILENAME_FILTER."

rows = []
for f in sorted(files):
    # Read with tolerant decoding
    try:
        html = f.read_text(encoding='utf-8', errors='ignore')
    except Exception:
        html = f.read_text(errors='ignore')
    soup = BeautifulSoup(html, 'html.parser')
    # Extract visible text (joins multiple <p> if present)
    text = soup.get_text(" ", strip=True)
    rows.append({
        "full_path": str(f),
        "filename": f.name,
        "response": text
    })

df = pd.DataFrame(rows)
print("Parsed submissions:", len(df))
df.head(3)
# Out:
# Found HTML files: 99
# Parsed submissions: 99
#                                            full_path         filename  \
# 0  /content/drive/MyDrive/2025 Fall/Data Journali...  onlinetext.html
# 1  /content/drive/MyDrive/2025 Fall/Data Journali...  onlinetext.html
# 2  /content/drive/MyDrive/2025 Fall/Data Journali...  onlinetext.html
#
#                                             response
# 0  I got the basics of data journalism. There wer...
# 1  Today's lesson was important, as it explained ...
# 2  Today’s introduction class with data journalis...

# %%
import re
from pathlib import Path

def parse_student_from_path(path: str):
    p = Path(path)
    student_folder = p.parent.name
    # Pattern: "Name Surname_12345_assignsubmission_onlinetext"
    m = re.match(r"^(?P<name>.+?)_(?P<id>\d{3,})_assignsubmission_onlinetext$", student_folder, flags=re.IGNORECASE)
    if m:
        return m.group("name").strip(), m.group("id")
    # Fallback: no ID part — just clean underscores
    return student_folder.replace("_", " ").strip(), ""

names, ids = [], []
for fp in df["full_path"]:
    name, sid = parse_student_from_path(fp)
    names.append(name)
    ids.append(sid)

df["student_name"] = names
df["student_id"]   = ids
df.head(5)
# Out:
#                                            full_path         filename  \
# 0  /content/drive/MyDrive/2025 Fall/Data Journali...  onlinetext.html
# 1  /content/drive/MyDrive/2025 Fall/Data Journali...  onlinetext.html
# 2  /content/drive/MyDrive/2025 Fall/Data Journali...  onlinetext.html
# 3  /content/drive/MyDrive/2025 Fall/Data Journali...  onlinetext.html
# 4  /content/drive/MyDrive/2025 Fall/Data Journali...  onlinetext.html
#
#                                             response          student_name  \
# 0  I got the basics of data journalism. There wer...  Aigerim Kalymzhanova
# 1  Today's lesson was important, as it explained ...   Aigerim Konysbekova
# 2  Today’s introduction class with data journalis...      Akniyet Oralgazy
# 3  Today's class was informative, Open Data types...       Alina Dalbekova
# 4  https://docs.google.com/document/d/1OVCoOQ0UuV...         Arsen Ilkenov
#
#   student_id
# 0     301296
# 1     301295
# 2     301290
# 3     301292
# 4     301283

# %%
import re
from pathlib import Path

def parse_week_and_title_from_seg(seg: str):
    s = seg.replace('—','-').replace('–','-').strip()
    # A) 'Week 5 ...'
    mA = re.search(r'\bweek\s*[-_ ]*(\d{1,2})\b', s, flags=re.IGNORECASE)
    if mA:
        w = int(mA.group(1))
        after = s[mA.end():].strip(" _-")
        title = after.split('-', 1)[0].strip()
        return w, title
    # B) '5 Week ...'
    mB = re.search(r'\b(\d{1,2})\s*[-_ ]*week\b', s, flags=re.IGNORECASE)
    if mB:
        w = int(mB.group(1))
        after = s[mB.end():].strip(" _-")
        title = after.split('-', 1)[0].strip()
        return w, title
    # C) Fallback: '05 - Title'
    mC = re.match(r'^(\d{1,2})\b\s*[-_ ]*([^-]*)', s)
    if mC:
        w = int(mC.group(1))
        if 1 <= w <= 30:  # avoid grabbing years like 2025
            title = (mC.group(2) or "").strip()
            return w, title
    return None, ""

def extract_week_from_path(path: str):
    p = Path(path)
    # Walk up folders (closest first), skipping the file name
    for seg in reversed(p.parts[:-1]):
        w, t = parse_week_and_title_from_seg(seg)
        if w is not None:
            return w, t
    return None, ""

weeks, titles = [], []
for fp in df["full_path"]:
    w, t = extract_week_from_path(fp)
    weeks.append(w)
    titles.append(t)

df["week_number"]     = weeks
df["assignment_title"] = titles
df.head(5)
# Out:
#                                            full_path         filename  \
# 0  /content/drive/MyDrive/2025 Fall/Data Journali...  onlinetext.html
# 1  /content/drive/MyDrive/2025 Fall/Data Journali...  onlinetext.html
# 2  /content/drive/MyDrive/2025 Fall/Data Journali...  onlinetext.html
# 3  /content/drive/MyDrive/2025 Fall/Data Journali...  onlinetext.html
# 4  /content/drive/MyDrive/2025 Fall/Data Journali...  onlinetext.html
#
#                                             response          student_name  \
# 0  I got the basics of data journalism. There wer...  Aigerim Kalymzhanova
# 1  Today's lesson was important, as it explained ...   Aigerim Konysbekova
# 2  Today’s introduction class with data journalis...      Akniyet Oralgazy
# 3  Today's class was informative, Open Data types...       Alina Dalbekova
# 4  https://docs.google.com/document/d/1OVCoOQ0UuV...         Arsen Ilkenov
#
#   student_id  week_number               assignment_title
# 0     301296            1  Attendance Reflect of the Day
# 1     301295            1  Attendance Reflect of the Day
# 2     301290            1  Attendance Reflect of the Day
# 3     301292            1  Attendance Reflect of the Day
# 4     301283            1  Attendance Reflect of the Day

# %%
def last_name(name: str):
    parts = [p for p in str(name).split() if p]
    return parts[-1].lower() if parts else ""

df["word_count"]   = df["response"].fillna("").str.split().apply(len)
df["last_name_key"] = df["student_name"].apply(last_name)

final_cols = ["student_name", "week_number", "assignment_title", "response", "word_count", "student_id", "full_path"]
final = (df
         .sort_values(["last_name_key", "week_number"], ascending=[True, True])
         [final_cols]
         .reset_index(drop=True))

print("✅ Final rows:", len(final))
final.head(10)
# Out:
# ✅ Final rows: 99
#          student_name  week_number                       assignment_title  \
# 0  Daniya Akimzhanova            3          Attendance Reflect of the Day
# 1  Daniya Akimzhanova            7          Attendance Reflect of the Day
# 2   Aruzhan Baimenova            1          Attendance Reflect of the Day
# 3   Aruzhan Baimenova            2          Attendance Reflect of the Day
# 4   Aruzhan Baimenova            3          Attendance Reflect of the Day
# 5   Aruzhan Baimenova            5  Attendance Reflect of the Project Day
# 6   Aruzhan Baimenova            6          Attendance Reflect of the Day
# 7   Aruzhan Baimenova            7          Attendance Reflect of the Day
# 8      Dilara Balkash            1          Attendance Reflect of the Day
# 9      Dilara Balkash            2          Attendance Reflect of the Day
#
#                                             response  word_count student_id  \
# 0  to create hypothesis we have to find problem, ...          62     313140
# 1  we watched the video about kenya and their sit...          35     386712
# 2  I was looking forward to this subject the most...          81     301282
# 3  We can use data to compare the information, an...          60     303472
# 4  Today I get to know about the main questions t...          79     313133
# 5  I actually got what I expected, all the topics...         121     340744
# 6  Data should contain the date in right way, by ...          64     366720
# 7  We watched a video project about malnutrition ...         144     386718
# 8  At today's lesson I learned new things and got...          66     301297
# 9  Metadata is data about data. When the data is ...          52     303466
#
#                                            full_path
# 0  /content/drive/MyDrive/2025 Fall/Data Journali...
# 1  /content/drive/MyDrive/2025 Fall/Data Journali...
# 2  /content/drive/MyDrive/2025 Fall/Data Journali...
# 3  /content/drive/MyDrive/2025 Fall/Data Journali...
# 4  /content/drive/MyDrive/2025 Fall/Data Journali...
# 5  /content/drive/MyDrive/2025 Fall/Data Journali...
# 6  /content/drive/MyDrive/2025 Fall/Data Journali...
# 7  /content/drive/MyDrive/2025 Fall/Data Journali...
# 8  /content/drive/MyDrive/2025 Fall/Data Journali...
# 9  /content/drive/MyDrive/2025 Fall/Data Journali...

# %%
OUT = str(BASE / "moodle_responses_sorted.xlsx")
final.to_excel(OUT, index=False)
print("📁 Saved:", OUT)
# Out:
# 📁 Saved: /content/drive/MyDrive/2025 Fall/Data Journalism 2025/Moodle Assignments/moodle_responses_sorted.xlsx
